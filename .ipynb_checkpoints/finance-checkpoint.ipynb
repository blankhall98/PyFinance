# %%
#librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ruta_litio = './data/LIT.csv'

# %%
litio = pd.read_csv(ruta_litio)

# %%
litio.head(3)
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2021-08-16  83.070000  83.070000  81.639999  82.010002  81.798904  1672100
# 1  2021-08-17  80.269997  80.650002  78.900002  79.739998  79.534744  1449500
# 2  2021-08-18  80.699997  81.580002  80.629997  80.790001  80.582047  1026100

# %%
litio['Date'] = pd.to_datetime(litio['Date'])

# %%
Y = 'ganancia_min_mx'
sns.lineplot(data=litio,x='Date',y=Y)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='ganancia_min_mx'>

# %%
litio['ganancia_min_mx'] = litio['High'] - litio['Close']

# %%
litio
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2021-08-16  83.070000  83.070000  81.639999  82.010002  81.798904
# 1   2021-08-17  80.269997  80.650002  78.900002  79.739998  79.534744
# 2   2021-08-18  80.699997  81.580002  80.629997  80.790001  80.582047
# 3   2021-08-19  80.959999  82.230003  80.800003  81.650002  81.439835
# 4   2021-08-20  81.230003  81.970001  80.970001  81.879997  81.669235
# ..         ...        ...        ...        ...        ...        ...
# 247 2022-08-09  77.410004  77.500000  76.860001  76.980003  76.980003
# 248 2022-08-10  77.839996  78.849998  77.410004  78.800003  78.800003
# 249 2022-08-11  79.760002  80.209999  79.160004  79.260002  79.260002
# 250 2022-08-12  79.330002  80.879997  78.830002  80.830002  80.830002
# 251 2022-08-15  80.730003  82.169998  80.309998  81.790001  81.790001
#
#       Volume  ganancia_min_mx
# 0    1672100         1.059998
# 1    1449500         0.910004
# 2    1026100         0.790001
# ...

# %%
sns.histplot(data=litio,x='ganancia_min_mx')
# Out:
# <AxesSubplot:xlabel='ganancia_min_mx', ylabel='Count'>

# %%
sns.relplot(data=litio,x='Volume',y='ganancia_min_mx',hue='Close')

# %%
sns.relplot(data=litio,x='Volume',y='Close',hue='ganancia_min_mx')

# %%
sns.lmplot(data=litio,x='Volume',y='Close')
